# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:\Datasets\iris.csv")
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
del df['Id']

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# * All features are numeric except Species

# %%
df.isnull().any()
# Out:
# SepalLengthCm    False
# SepalWidthCm     False
# PetalLengthCm    False
# PetalWidthCm     False
# Species          False
# dtype: bool

# %% [markdown]
# * Their are no Null values.

# %%
df.describe().T
# Out:
#                count      mean       std  min  25%   50%  75%  max
# SepalLengthCm  150.0  5.843333  0.828066  4.3  5.1  5.80  6.4  7.9
# SepalWidthCm   150.0  3.054000  0.433594  2.0  2.8  3.00  3.3  4.4
# PetalLengthCm  150.0  3.758667  1.764420  1.0  1.6  4.35  5.1  6.9
# PetalWidthCm   150.0  1.198667  0.763161  0.1  0.3  1.30  1.8  2.5

# %% [markdown]
# * No outliers in Data

# %% [markdown]
# # EDA

# %%
col=['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']

# %%
n=0
plt.figure(1,figsize=(10,10))
for i in col:
    n+=1
    plt.subplot(2,2,n)
    plt.subplots_adjust(hspace=1, wspace=0.5)
    sns.boxplot(df[i])
    plt.title("Boxplot of {}".format(i))
plt.show()

# %% [markdown]
# * There are some outliers in SepalWidth

# %%
n=0
plt.figure(1,figsize=(10,10))
for i in col:
    n+=1
    plt.subplot(2,2,n)
    plt.subplots_adjust(hspace=1, wspace=0.5)
    sns.distplot(df[i])
    plt.title("Disttribution of {}".format(i))
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_7676\1121268878.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i])
# C:\Users\admin\AppData\Local\Temp\ipykernel_7676\1121268878.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i])
# ...

# %% [markdown]
# * SepalLength & Sepal Width have Normal Distribution.

# %%
sns.pairplot(df,hue='Species')

# %% [markdown]
# * We can eassily classify Species based on Petal Length & Petal Width

# %% [markdown]
# ### Sepal Length

# %%
plt.figure(figsize=(15,8))
sns.histplot(data=df, x='SepalLengthCm', kde=True, hue='Species', multiple='dodge')
plt.title("Area Distribution", fontsize=15)
plt.show()

# %% [markdown]
# * Each Species have Different peaks.But All of them are somewhat overlapping.

# %%
sns.catplot(data=df, y='SepalLengthCm', x='Species', kind='box')
plt.title("Area Distribution")
plt.show()

# %% [markdown]
# #### Result:-

# %% [markdown]
# Species have lower value of Sepal Length are Setosa while Species have Higher values of Sepal Length are Virginica.

# %% [markdown]
# * Based on Sepal Length we can easily classify Species.

# %% [markdown]
# ### Sepal Width

# %%
plt.figure(figsize=(15,8))
sns.histplot(data=df, x='SepalWidthCm', kde=True, hue='Species', multiple='dodge')
plt.title("Area Distribution", fontsize=15)
plt.show()

# %% [markdown]
# * Setosa have lower peak. Versicolor & Virginica almost have same peak. All Species have Overlapping Distributions.

# %%
sns.catplot(data=df, y='SepalWidthCm', x='Species', kind='box')
plt.title("Area Distribution")
plt.show()

# %% [markdown]
# #### Result:-

# %% [markdown]
# Species have lower value of Sepal Width are Versicolor while Species have Lower values of Sepal Length are Setosa.

# %% [markdown]
# * As we can see values are overlapping so, Based on Sepal Width we can not easily classify Species.

# %% [markdown]
# ### Petal Length

# %%
plt.figure(figsize=(15,8))
sns.histplot(data=df, x='PetalLengthCm', kde=True, hue='Species', multiple='dodge')
plt.title("Area Distribution", fontsize=15)
plt.show()

# %% [markdown]
# * Each Species have Different peaks. But versicolor and verginica are overlapping.

# %%
sns.catplot(data=df, y='PetalLengthCm', x='Species', kind='box')
plt.title("Area Distribution")
plt.show()

# %% [markdown]
# #### Result:-

# %% [markdown]
# Species have lower value of Petal Length are Setosa while Species have Higher values of Sepal Length are Virginica.

# %% [markdown]
# * Based on Sepal Length we can classify Species.

# %% [markdown]
# ### Petal Width

# %%
plt.figure(figsize=(15,8))
sns.histplot(data=df, x='PetalWidthCm', kde=True, hue='Species', multiple='dodge')
plt.title("Area Distribution", fontsize=15)
plt.show()

# %% [markdown]
# * Each Species have Different peaks. But versicolor and verginica are overlapping.

# %%
sns.catplot(data=df, y='PetalWidthCm', x='Species', kind='box')
plt.title("Area Distribution")
plt.show()

# %% [markdown]
# #### Result:-

# %% [markdown]
# Species have lower value of Petal Width are Setosa while Species have Higher values of Sepal Length are Virginica.

# %% [markdown]
# * Based on Petal Width we can easily classify Species.

# %%
df['Species'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# * Data is Balanced.

# %% [markdown]
# # Splitting Data

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (120, 4)
# (30, 4)
# (120,)
# (30,)

# %% [markdown]
# # Model Fitting

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt=DecisionTreeClassifier()

# %%
model=dt.fit(x_train,y_train)

# %% [markdown]
# ## Visualizing Decision Tree

# %%
from sklearn import tree

# %%
plt.figure(figsize=(20,15))
_=tree.plot_tree(model,
                feature_names=['sepal_length', 'sepal_width', 'petal_length', 'petal_width'],
                class_names=['Setosa','Verginica','Versicolor'], 
                filled=True)

# %% [markdown]
# ## Evaluation of Model

# %%
y_pred=dt.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report

# %%
print(accuracy_score(y_test,y_pred)*100)
# Out:
# 100.0

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[11  0  0]
#  [ 0 13  0]
#  [ 0  0  6]]

# %%
print(classification_report(y_test,y_pred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        11
# Iris-versicolor       1.00      1.00      1.00        13
#  Iris-virginica       1.00      1.00      1.00         6
#
#        accuracy                           1.00        30
#       macro avg       1.00      1.00      1.00        30
#    weighted avg       1.00      1.00      1.00        30
